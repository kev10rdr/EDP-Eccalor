# %% [markdown]
# <a href="https://colab.research.google.com/github/kev10rdr/EDP-Eccalor/blob/main/Segundoproblemaecc_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Análisis de una solución de la ecuación del calor

# %% [markdown]
# La solución de la ecuación
# $$\frac{\partial u}{\partial t} = \frac{\partial^2 u}{\partial x^2}$$
# sujeta a las condiciones de frontera:
# $$\frac{\partial u(0,t)}{\partial x}=\frac{\partial u(1,t)}{\partial x}=0, \;\;\; t>0$$
# Y la condición inicial:
# $$ \begin{equation} u(x,0) =
# \begin{matrix}-2,\ si\ 0<x\le\frac{1}{2}\\
# 0,\ si\ \frac{1}{2}<x<1\\
# \end{matrix}.
# \end{equation} $$
#
# Esta dada en términos de la serie de Fourier por la expresión:
# $$u(x,t)=-(1+\frac{4}{\pi}\sum_{n=1}^{\infty} \frac{sen(\frac{n \pi}{2})}{n}  \cos(n\pi x)e^{-(n\pi)^2 t}).$$

# %% [markdown]
# Este problema modela la transferencia de calor en una barra ideal delgada, con $k=1$.

# %%
from pylab import *

# %% [markdown]
# Para empezar, graficamos la condición inicial.

# %%
def recta(x):
    y = zeros(len(x))
    for i in range(len(x)):
        y[i] = -2
    return y

# %%
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(0,1,200)
x1 = np.linspace(0, 0.5,3)
x2 = np.linspace(0.5, 1,2)

plot(x1, [-2 for x in x1],label='$a(x)$ = -2, x en $[0, 0.5]$')
plot(x2, [0 for x in x2],label='$b(x)$ = 0, x en $[0.5, 1]$')

plt.xlabel('$x$'); plt.ylabel('$f(x)$'); 
plt.title("Condición inicial (u(x,0)=f(x))"),grid(),legend()
show()

# %% [markdown]
# Usamos una serie de Fourier para aproximar la condición inicial $u(x,0)=f(x)=
#   \begin{matrix}-2,\ si\ 0<x\le\frac{1}{2}\\
#   0,\ si\ \frac{1}{2}<x<1\\
#   \end{matrix}.$.

# %%
def u_0(x,N=30): 
    f = zeros(len(x))
    for n in range(1,N):
        f += (sin((n*pi)/(2))*cos(n*pi*x))/(n)
    return (-(1.0+(4.0/pi)*f))

# %%
f_n = u_0(x)
plot(x,f_n,label='$f_N(x)$ con $N=30$')

plot(x1, [-2 for x in x1],label='$a(x) = -2, 0 <x < 1/2$')
plot(x2, [0 for x in x2],label='$b(x) = 0, 1/2<x <1$')
plt.xlabel('$x$'); plt.ylabel('$f(x)$'); 
plt.title("Aproximación de la condición inicial")
xlim([-0.01,1.01]),ylim([-3.01,0.5]),grid(),legend()
show()

# %% [markdown]
# Podemos visualizar la aproximación para diferentes cantidades de armónicos.

# %%
for i in range(1,30,6):
    plot(x,u_0(x,i),label='$f_N(x)$ con $N=%d$' %i)
plt.xlabel('$x$'); plt.ylabel('$f(x)$'); 
plt.title("Aproximación de la condición inicial")
xlim([-0.01,1.01]),ylim([-2.24,0.4]),grid(),legend()
show()

# %% [markdown]
# Ahora, agregamos la parte temporal para visualizar la solución completa. Primero, para el momento inicial, $t=0$.

# %%
def u_x_t(x,t,N=100):
    f = zeros( (len(x),len(t)) )
    for i in range(len(t)):
        for n in range(1,N):
            f[:,i] += (sin((n*pi)/(2))*cos(n*pi*x))/(n)*exp(-n**2*pi**2*t[i])
    return (-(1.0+(4.0/pi)*f))

# %%
x = linspace(0,1,1000)
t = linspace(0,10,1000)
U = u_x_t(x,t)

# %%
plot(x,U[:,0],label='$u(x,0)$')
plt.xlabel('$x$'); plt.ylabel('$f(x)$'); 
plt.title("Aproximación de la condición inicial")
xlim([-0.01,1.01]),ylim([-2.21,0.4]),grid(),legend()
show()

# %% [markdown]
# Luego, para diferentes tiempos, lo cual nos permite ver cómo la solución evoluciona cuando $t \to \infty$.

# %%
plot(x,U[:,0],label='$u(x,0)$') 
plot(x,U[:,1],label='$u(x,1)$')
plot(x,U[:,5],label='$u(x,5)$')
plot(x,U[:,3],label='$u(x,3)$')
plot(x,U[:,10],label='$u(x,10)$')
plot(x,U[:,20],label='$u(x,20)$')
plt.xlabel('$x$'); plt.ylabel('$u(x,t)$'); 
plt.title("Evolución de la solución")
xlim([-0.01,1.01]),ylim([-2.25,0.25]),grid(),legend()
show()

# %% [markdown]
# Y podemos ver esto en una gráfica en 3D.

# %%
#%matplotlib notebook
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(12,10))
ax = fig.add_subplot(111, projection="3d")

x = linspace(0,1.0,100)
t = linspace(0,1.0,100)

X,T = np.meshgrid(x,t)

U = u_x_t(x,t)

plt.xlabel('$t$'); plt.ylabel('$x$'); 
plt.title('$u(x,t)=-1-\dfrac{4}{\pi}\sum_{n=1}^{\infty}\dfrac{1}{n}sen(\dfrac{n \pi}{2})cos(n\pi x)e^{-(n\pi)^2t}$')
ax.plot_surface(X, T, U, cmap="viridis");
